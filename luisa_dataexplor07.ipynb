# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/cmrivers/ebola/master/country_timeseries.csv',
                 index_col=0)

# %%
#reproduce epidemic curves for each county

# %%
data.head()
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 11/2/2014   225          1731            NaN               4759
# 10/31/2014  222           NaN           6525                NaN
# 10/29/2014  220          1667            NaN               5338
# 10/27/2014  218          1906            NaN               5235
# 10/25/2014  216           NaN           6535                NaN
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 11/2/2014              20              1                   4            1
# 10/31/2014            NaN            NaN                 NaN          NaN
# 10/29/2014             20              1                   4            1
# 10/27/2014             20              1                   4            1
# 10/25/2014            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# ...

# %%
data.describe()
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# count   94.000000     75.000000      67.000000          69.000000
# mean   111.000000    558.653333    1088.343284         982.202899
# std     72.266681    465.340895    1685.270328        1346.569100
# min      0.000000     49.000000       3.000000           0.000000
# 25%     40.500000    225.000000      13.000000           2.000000
# 50%    113.000000    410.000000     172.000000         442.000000
# 75%    178.250000    791.500000    1538.000000        1424.000000
# max    225.000000   1906.000000    6535.000000        5338.000000
#
#        Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# count      30.000000      17.000000           10.000000            8
# mean       15.866667       1.117647            2.700000            1
# std         6.495268       0.485071            1.337494            0
# min         0.000000       1.000000            1.000000            1
# ...

# %%
data.interpolate()
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 11/2/2014   225   1731.000000            NaN        4759.000000
# 10/31/2014  222   1699.000000    6525.000000        5048.500000
# 10/29/2014  220   1667.000000    6528.333333        5338.000000
# 10/27/2014  218   1906.000000    6531.666667        5235.000000
# 10/25/2014  216   1788.333333    6535.000000        4565.500000
# 10/22/2014  214   1670.666667    6067.500000        3896.000000
# 10/21/2014  213   1553.000000    5600.000000        3801.000000
# 10/19/2014  211   1540.000000    5132.500000        3706.000000
# 10/18/2014  210   1529.500000    4665.000000        3558.000000
# 10/14/2014  206   1519.000000    4463.500000        3410.000000
# 10/13/2014  205   1495.500000    4262.000000        3331.000000
# 10/12/2014  204   1472.000000    4255.500000        3252.000000
# 10/11/2014  203   1431.333333    4249.000000        3101.000000
# 10/8/2014   200   1390.666667    4162.500000        2950.000000
# ...

# %%
data.fillna(method='bfill')
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 11/2/2014   225          1731           6525               4759
# 10/31/2014  222          1667           6525               5338
# 10/29/2014  220          1667           6535               5338
# 10/27/2014  218          1906           6535               5235
# 10/25/2014  216          1553           6535               3896
# 10/22/2014  214          1553           4665               3896
# 10/21/2014  213          1553           4665               3706
# 10/19/2014  211          1540           4665               3706
# 10/18/2014  210          1519           4665               3410
# 10/14/2014  206          1519           4262               3410
# 10/13/2014  205          1472           4262               3252
# 10/12/2014  204          1472           4249               3252
# 10/11/2014  203          1350           4249               2950
# 10/8/2014   200          1350           4076               2950
# ...

# %%
data.columns
# Out:
# Index([u'Day', u'Cases_Guinea', u'Cases_Liberia', u'Cases_SierraLeone', u'Cases_Nigeria', u'Cases_Senegal', u'Cases_UnitedStates', u'Cases_Spain', u'Cases_Mali', u'Deaths_Guinea', u'Deaths_Liberia', u'Deaths_SierraLeone', u'Deaths_Nigeria', u'Deaths_Senegal', u'Deaths_UnitedStates', u'Deaths_Spain', u'Deaths_Mali'], dtype='object')

# %%
cases = []
deaths = []
data.set_index = ['date']

for column in data.columns:
    tmp =  column.split('_')
    if tmp[0] == 'Cases':
        cases.append(column)
    if tmp[0] == 'Deaths':
        deaths.append(column)

# %%
print cases
# Out:
# ['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone', 'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain', 'Cases_Mali']

# %%
print deaths
# Out:
# ['Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone', 'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates', 'Deaths_Spain', 'Deaths_Mali']

# %%
deaths_data = data[deaths]

# %%
cases_data = data[cases]

# %%
cases_data.plot()

# %%
deaths_data.plot()

# %%
liberia = pd.DataFrame(deaths_data.Deaths_Liberia, index=deaths_data.index )

# %%
liberia.plot()

# %%
import seaborn as sns

lagged = pd.concat([liberia.shift(i) for i in range(10)], axis= 1)
lagged.columns =("lag%.2d"%(i) for i in range(10))
sns.corrplot(lagged)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=bold:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
cases_data.head(2)
# Out:
#             Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Date
# 11/2/2014           1731            NaN               4759             20
# 10/31/2014           NaN           6525                NaN            NaN
#
#             Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali
# Date
# 11/2/2014               1                   4            1           1
# 10/31/2014            NaN                 NaN          NaN         NaN

# %%
deaths_data.head(2)
# Out:
#             Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Date
# 11/2/2014            1041             NaN                1070               8
# 10/31/2014            NaN            2697                 NaN             NaN
#
#             Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# Date
# 11/2/2014                0                    1             0            1
# 10/31/2014             NaN                  NaN           NaN          NaN

# %%
cases_data.columns = ['Guinea', 'Liberia', 'SierraLeone', 'Nigeria', 'Senegal', 'UnitedStates', 'Spain', 'Mali']
cases_data.head(2)
# Out:
#             Guinea  Liberia  SierraLeone  Nigeria  Senegal  UnitedStates  \
# Date
# 11/2/2014     1731      NaN         4759       20        1             4
# 10/31/2014     NaN     6525          NaN      NaN      NaN           NaN
#
#             Spain  Mali
# Date
# 11/2/2014       1     1
# 10/31/2014    NaN   NaN

# %%
deaths_data.columns = ['Guinea', 'Liberia', 'SierraLeone', 'Nigeria', 'Senegal', 'UnitedStates', 'Spain', 'Mali']
deaths_data.head(2)
# Out:
#             Guinea  Liberia  SierraLeone  Nigeria  Senegal  UnitedStates  \
# Date
# 11/2/2014     1041      NaN         1070        8        0             1
# 10/31/2014     NaN     2697          NaN      NaN      NaN           NaN
#
#             Spain  Mali
# Date
# 11/2/2014       0     1
# 10/31/2014    NaN   NaN

# %%
cases_data['daily_total'] = cases_data.sum(axis=1)
cases_data['group'] = cases_data.apply(lambda col: 'cases')
cases_data['group'] = cases_data['group'].fillna('cases')
deaths_data['daily_total'] = deaths_data.sum(axis=1)
deaths_data['group'] = deaths_data.apply(lambda col: 'deaths')
deaths_data['group'] = deaths_data['group'].fillna('deaths')
# Out:
# -c:3: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:6: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
deaths_data.head(2)
# Out:
#             Guinea  Liberia  SierraLeone  Nigeria  Senegal  UnitedStates  \
# Date
# 11/2/2014     1041      NaN         1070        8        0             1
# 10/31/2014     NaN     2697          NaN      NaN      NaN           NaN
#
#             Spain  Mali  daily_total   group
# Date
# 11/2/2014       0     1         2121  deaths
# 10/31/2014    NaN   NaN         2697  deaths

# %%
cases_data.head(2)
# Out:
#             Guinea  Liberia  SierraLeone  Nigeria  Senegal  UnitedStates  \
# Date
# 11/2/2014     1731      NaN         4759       20        1             4
# 10/31/2014     NaN     6525          NaN      NaN      NaN           NaN
#
#             Spain  Mali  daily_total  group
# Date
# 11/2/2014       1     1         6517  cases
# 10/31/2014    NaN   NaN         6525  cases

# %%
data = cases_data

# %%
data = data.append(deaths_data)

# %%
cases = [col for col in cases_data if col != 'group']
cases = cases_data[cases]

deaths = [col for col in deaths_data if col != 'group']
deaths = deaths_data[deaths]

# %%
cases_total = cases.sum()
deaths_total = deaths.sum()

# %%
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})

sns.barplot(x = cases.columns, y = cases_total, color = "red")
bottom_plot = sns.barplot(x = deaths.columns, y = deaths_total, color = "#0000A3")

topbar = plt.Rectangle((0,0),1,1,fc="red", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='#0000A3',  edgecolor = 'none')
l = plt.legend([bottombar, topbar], ['Cases', 'Deaths'], loc=1, ncol = 2, prop={'size':16})
l.draw_frame(False)

sns.despine(left=True)
bottom_plot.set_ylabel("cases+deaths")
bottom_plot.set_xlabel("country")
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=16.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
cases_total
# Out:
# Guinea           41899
# Liberia          72919
# SierraLeone      67772
# Nigeria            476
# Senegal             19
# UnitedStates        27
# Spain                8
# Mali                 4
# daily_total     183124
# dtype: float64

# %%
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})



sns.barplot(x = data.group, y = data['Liberia'], color = "blue")
sns.barplot(x = data.group, y=data['SierraLeone'], color = "yellow")
sns.barplot(x=data.group, y=data['Guinea'], color = "red")
sns.barplot(x = data.group, y=data['Nigeria'], color="green")
sns.barplot(x = data.group, y=data['Senegal'], color="purple")
sns.barplot(x = data.group, y=data['UnitedStates'], color="purple")
sns.barplot(x = data.group, y=data['Spain'], color = "white")
sns.barplot(x = data.group, y=data['Mali'], color="black")

sns.despine(left=True)
bottom_plot.set_ylabel("country")
bottom_plot.set_xlabel("group")

# %%
###Use TimeSeriesModeller() to estimate a lagged model for each country what about the TimeSeriesModeller class makes it not ideal for quickly changing epidemic data? 
####4. Modify the way TimeSeriesModeller() selects the training set so that it fits the

# %%
#### TimeSeriesModeller from lecture


from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error


class TimeSeriesModeller:
    def __init__(self):
        self.model = LinearRegression()
        
    def fit(self,y):
        for ar_size in range(1,10):
            train_start = int(len(y)/2)
            lagged = pd.concat([Y.shift(i) for i in range(1,ar_size+1)], axis=1)
            self.model.fit(lagged.ix[11:train_start],y.ix[11:train_start])
            predictions = []
            for t in range(train_start, len(y)):
                prediction = self.model.predict(lagged.ix[t])
                predictions.append(prediction/y.ix[t]-1)
            error = mean(predictions)
            print "model size%f" %(ar_size)      
            print "meansquarederror %f"%(error)

# %%
modeller = TimeSeriesModeller()

# %%
cases = cases.fillna(method='ffill')

# %%
for i in xrange(0, len(cases.columns)):
    Y = cases[cases.columns[i]]
    print cases.columns[i]
    modeller.fit(Y)
# Out:
# Guinea
# model size1.000000
# meansquarederror 0.005111
# model size2.000000
# meansquarederror 0.006296
# model size3.000000
# meansquarederror 0.010356
# model size4.000000
# meansquarederror 0.029070
# model size5.000000
# meansquarederror 0.018523
# model size6.000000
# meansquarederror 0.019745
# model size7.000000
# meansquarederror 0.007520
# model size8.000000
# meansquarederror -0.007782
# model size9.000000
# meansquarederror 0.005851
# Liberia
# model size1.000000
# meansquarederror -6.285656
# model size2.000000
# meansquarederror -4.595680
# model size3.000000
# meansquarederror -5.412175
# model size4.000000
# meansquarederror -5.633133
# model size5.000000
# meansquarederror -5.521807
# model size6.000000
# meansquarederror -6.047331
# model size7.000000
# meansquarederror -5.848986
# model size8.000000
# meansquarederror -7.016319
# model size9.000000
# meansquarederror -6.191905
# SierraLeone
# model size1.000000
# meansquarederror nan
# model size2.000000
# ...
