# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import Ebola Data #
df = pd.DataFrame.from_csv('https://raw.githubusercontent.com/cmrivers/ebola/master/country_timeseries.csv',
                 index_col=0)

# %%
#reproduce epidemic curves for each county

df = df.fillna(method = 'bfill') # will fill data from first data point
# df = df.interpolate() # will fill data before data points

# The data from the most recent day
mostrecent = df[0:1]

# %%
# Split data into cases and deaths
cases_column = []
deaths_column = []

# %%
for column in df.columns:
    head = column.split('_')
    if head[0] == 'Cases':
        cases_column.append(column)
    if head[0] == 'Deaths':
        deaths_column.append(column)

# %%
# Plot Cases and Deaths
cases = df[cases_column]
cases.plot()
show()

deaths = df[deaths_column]
deaths.plot()
show()

# %%
# Lag Corr Plots

def acf(df):
    import seaborn as sns
    lagged = pd.concat([df.shift(i) for i in range(10)], axis=1)
    lagged.columns = ["lag%s"%i for i in range(10)]
    sns.corrplot(lagged)

# %%
for c in deaths.columns:
    print c
    acf(deaths[c])
    show()
# Out:
# Deaths_Guinea
# Deaths_Liberia
# Deaths_SierraLeone
# Deaths_Nigeria
# Deaths_Senegal
# Deaths_UnitedStates
# Deaths_Spain
# Deaths_Mali

# %%
for c in cases.columns:
    print c
    acf(cases[c])
    show()
# Out:
# Cases_Guinea
# Cases_Liberia
# Cases_SierraLeone
# Cases_Nigeria
# Cases_Senegal
# Cases_UnitedStates
# Cases_Spain
# Cases_Mali

# %%
# Create DataFrame From Most Recent Data
mr_cases = mostrecent[cases_column].T.values
mr_deaths = mostrecent[deaths_column].T.values

# %%
# Get a list of countries
countries = []

# %%
for column in cases_column:
    head = column.split('_')
    countries.append(head[1])

# %%
stacked = pd.DataFrame(index = countries, columns = ['Cases', 'Deaths'])
stacked['Cases'] = sum_cases
stacked['Deaths'] = sum_deaths
stacked
# Out:
#               Cases  Deaths
# Guinea         1731    1041
# Liberia        6525    2697
# SierraLeone    4759    1070
# Nigeria          20       8
# Senegal           1       0
# UnitedStates      4       1
# Spain             1       0
# Mali              1       1

# %%
stacked = stacked.rename(index = {'SierraLeone' : 'Sierra Leone', 'UnitedStates' : 'United States'})

# %%
# Stacked Bar Plots
N = len(stacked)
width = 0.5
ind = np.arange(N)
red, blue = '#EF3340', '#0085CA'

# %%
# All the data in one graph

p1 = plt.bar(ind, stacked.Deaths, width, color = red, label = 'Deaths')
p2 = plt.bar(ind, stacked.Cases, width, bottom = stacked.Deaths, color = blue, label = 'Cases')
plt.xticks(ind+width/2., stacked.index, rotation = 45)
plt.ylabel('Number')
plt.title('Ebola Cases And Deaths')
plt.show()

# Transform so we can see all the data
stacked_norm = (1. * stacked.T / stacked.T.sum()).T

p4 = plt.bar(ind, stacked_norm.Deaths, width, color = red, label = 'Deaths')
p5 = plt.bar(ind, stacked_norm.Cases, width, bottom = stacked_norm.Deaths, color = blue, label = 'Cases')
plt.ylabel('%')
plt.title('Normalized Data')
plt.xticks(ind + width / 2., stacked.index, rotation = 45)
plt.show()

# %%
# Time Series Modeller

from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

class TimeSeriesModeller:
    def __init__(self):
        self.model = LinearRegression()
        
    def fit(self,y):
        for ar_size in range(1,10):
            train_start = int(len(y)/2)
            lagged = pd.concat([Y.shift(i) for i in range(1,ar_size+1)], axis=1)
            self.model.fit(lagged.ix[11:train_start],y.ix[11:train_start])
            predictions = []
            for t in range(train_start, len(y)):
                prediction = self.model.predict(lagged.ix[t])
                predictions.append(prediction/y.ix[t]-1)
            error = mean(predictions)
            print "model size: %s"%(ar_size)
            print "meansquarederror %f"%(error)

# Modified TimeSeriesModeller

    def fit_day_late(self,y):
        for ar_size in range(1,10):
            train_start = int(len(y[1:])/2) # Modified Line
            lagged = pd.concat([Y.shift(i) for i in range(1,ar_size+1)], axis=1)
            self.model.fit(lagged.ix[11:train_start],y.ix[11:train_start])
            predictions = []
            for t in range(train_start, len(y)):
                prediction = self.model.predict(lagged.ix[t])
                predictions.append(prediction/y.ix[t]-1)
            error = mean(predictions)
            print "model size: %s"%(ar_size)
            print "meansquarederror %f"%(error)

# %%
# Dictionary Cases and Deaths By Country
totals = {name: df[['Cases_' + name, 'Deaths_' + name]].dropna() for name in countries}

# %%
modeller = TimeSeriesModeller()

# %%
# Regular TimesSeriesModeller
for total in totals:
    try: 
        Y = totals[total]
        print total
        print ""
        print 'Cases ' + total
        modeller.fit(Y['Cases_' + total])
        print ""
        print 'Deaths ' + total
        modeller.fit(Y['Deaths_' + total])
        print ""
    except:
        pass
# Out:
# Liberia
#
# Cases Liberia
# model size: 1
# meansquarederror -4.795015
# model size: 2
# meansquarederror -3.299493
# model size: 3
# meansquarederror -4.059261
# model size: 4
# meansquarederror -3.626591
# model size: 5
# meansquarederror -1.898014
# model size: 6
# meansquarederror -2.501359
# model size: 7
# meansquarederror -1.470932
# model size: 8
# meansquarederror -2.759364
# model size: 9
# meansquarederror -3.092198
#
# Deaths Liberia
# model size: 1
# meansquarederror -4.407713
# model size: 2
# meansquarederror -2.050010
# model size: 3
# meansquarederror -1.411624
# model size: 4
# meansquarederror -3.108319
# model size: 5
# meansquarederror -1.331081
# model size: 6
# meansquarederror -1.925202
# model size: 7
# meansquarederror -1.045168
# model size: 8
# meansquarederror -0.787531
# model size: 9
# meansquarederror -1.681061
#
# Guinea
#
# Cases Guinea
# model size: 1
# meansquarederror -0.153083
# model size: 2
# meansquarederror -0.098837
# model size: 3
# meansquarederror -0.008524
# model size: 4
# meansquarederror -0.202704
# model size: 5
# meansquarederror 0.031298
# model size: 6
# meansquarederror 0.035748
# model size: 7
# meansquarederror -0.072204
# model size: 8
# meansquarederror 0.124811
# model size: 9
# meansquarederror 0.031129
#
# Deaths Guinea
# model size: 1
# meansquarederror 0.066811
# model size: 2
# meansquarederror 0.149173
# model size: 3
# meansquarederror 0.206171
# model size: 4
# meansquarederror 0.060492
# model size: 5
# meansquarederror 0.254048
# model size: 6
# meansquarederror 0.325328
# model size: 7
# meansquarederror 0.371883
# model size: 8
# meansquarederror 0.556026
# model size: 9
# meansquarederror 0.294244
#
# SierraLeone
#
# Cases SierraLeone
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror -inf
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Deaths SierraLeone
# model size: 1
# meansquarederror inf
# model size: 2
# meansquarederror inf
# model size: 3
# meansquarederror inf
# model size: 4
# meansquarederror inf
# model size: 5
# meansquarederror inf
# model size: 6
# meansquarederror inf
# model size: 7
# meansquarederror inf
# model size: 8
# meansquarederror inf
# model size: 9
# meansquarederror inf
#
# Senegal
#
# Cases Senegal
# model size: 1
# meansquarederror 0.058824
# model size: 2
# meansquarederror 0.080000
# model size: 3
# meansquarederror 0.062500
# model size: 4
# meansquarederror 0.076923
# model size: 5
# meansquarederror 0.066667
# model size: 6
# meansquarederror 0.078431
# model size: 7
# meansquarederror 0.071429
# model size: 8
# meansquarederror 0.081967
# model size: 9
# meansquarederror 0.076923
#
# Deaths Senegal
# model size: 1
# meansquarederror nan
# model size: 2
# meansquarederror nan
# model size: 3
# meansquarederror nan
# model size: 4
# meansquarederror nan
# model size: 5
# meansquarederror nan
# model size: 6
# meansquarederror nan
# model size: 7
# meansquarederror nan
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Mali
#
# Cases Mali
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Mali
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Nigeria
#
# Cases Nigeria
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror inf
# model size: 6
# meansquarederror inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror -inf
# model size: 9
# meansquarederror -inf
#
# Deaths Nigeria
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror inf
# model size: 5
# meansquarederror inf
# model size: 6
# meansquarederror inf
# model size: 7
# meansquarederror inf
# model size: 8
# meansquarederror inf
# model size: 9
# meansquarederror nan
#
# Spain
#
# Cases Spain
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Spain
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# UnitedStates
#
# Cases UnitedStates
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.006410
# model size: 3
# meansquarederror -0.000000
# model size: 4
# meansquarederror 0.057276
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.004082
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths UnitedStates
# model size: 1
# meansquarederror inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror inf
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror inf
# model size: 8
# meansquarederror -inf
# model size: 9
# meansquarederror inf

# %%
# Most Recent Data Point Excluded TimesSeriesModeller
for total in totals:
    try: 
        Y = totals[total]
        print total
        print ""
        print 'Cases ' + total
        modeller.fit_day_late(Y['Cases_' + total])
        print ""
        print 'Deaths ' + total
        modeller.fit(Y_day_late['Deaths_' + total])
        print ""
    except:
        pass
# Out:
# Liberia
#
# Cases Liberia
# model size: 1
# meansquarederror -5.022861
# model size: 2
# meansquarederror -3.508850
# model size: 3
# meansquarederror -4.374172
# model size: 4
# meansquarederror -4.125199
# model size: 5
# meansquarederror -2.395413
# model size: 6
# meansquarederror -3.275559
# model size: 7
# meansquarederror -2.357059
# model size: 8
# meansquarederror -4.090205
# model size: 9
# meansquarederror -4.948956
#
# Deaths Liberia
# Guinea
#
# Cases Guinea
# model size: 1
# meansquarederror -0.184874
# model size: 2
# meansquarederror -0.139145
# model size: 3
# meansquarederror -0.055243
# model size: 4
# meansquarederror -0.248973
# model size: 5
# meansquarederror -0.002690
# model size: 6
# meansquarederror 0.003181
# model size: 7
# meansquarederror -0.118235
# model size: 8
# meansquarederror 0.059077
# model size: 9
# meansquarederror -0.025396
#
# Deaths Guinea
# SierraLeone
#
# Cases SierraLeone
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror -inf
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Deaths SierraLeone
# Senegal
#
# Cases Senegal
# model size: 1
# meansquarederror 0.060606
# model size: 2
# meansquarederror 0.082474
# model size: 3
# meansquarederror 0.064516
# model size: 4
# meansquarederror 0.079470
# model size: 5
# meansquarederror 0.068966
# model size: 6
# meansquarederror 0.081218
# model size: 7
# meansquarederror 0.074074
# model size: 8
# meansquarederror 0.085106
# model size: 9
# meansquarederror 0.080000
#
# Deaths Senegal
# Mali
#
# Cases Mali
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Mali
# Nigeria
#
# Cases Nigeria
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror nan
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror -inf
#
# Deaths Nigeria
# Spain
#
# Cases Spain
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Spain
# UnitedStates
#
# Cases UnitedStates
# model size: 1
# meansquarederror -0.000000
# model size: 2
# meansquarederror 0.006623
# model size: 3
# meansquarederror -0.000000
# model size: 4
# meansquarederror 0.066858
# model size: 5
# meansquarederror 0.032396
# model size: 6
# meansquarederror 0.036383
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror -0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths UnitedStates

# %%
# Log Transformation
log_df = np.log(df)

# %%
log_df.head()
# Out:
#                  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-11-02  5.416100      7.456455       8.783396           8.467793
# 2014-10-31  5.402677      7.418781       8.783396           8.582606
# 2014-10-29  5.393628      7.418781       8.784928           8.582606
# 2014-10-27  5.384495      7.552762       8.784928           8.563122
# 2014-10-25  5.375278      7.347944       8.784928           8.267706
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2014-11-02       2.995732              0            1.386294            0
# 2014-10-31       2.995732              0            1.386294            0
# 2014-10-29       2.995732              0            1.386294            0
# 2014-10-27       2.995732              0            1.386294            0
# 2014-10-25       2.995732              0            1.386294            0
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2014-11-02           0       6.947937        7.899895            6.975414
# 2014-10-31           0       6.925595        7.899895            7.319865
# 2014-10-29           0       6.925595        7.788626            7.319865
# 2014-10-27           0       6.904751        7.788626            7.313220
# 2014-10-25           0       6.830874        7.788626            7.155396
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2014-11-02        2.079442            -inf                    0          -inf
# 2014-10-31        2.079442            -inf                    0          -inf
# 2014-10-29        2.079442            -inf                    0          -inf
# 2014-10-27        2.079442            -inf                    0          -inf
# 2014-10-25        2.079442            -inf                    0          -inf
#
#             Deaths_Mali
# Date
# 2014-11-02            0
# 2014-10-31            0
# 2014-10-29            0
# 2014-10-27            0
# 2014-10-25            0

# %%
log_totals = {name: log_df[['Cases_' + name, 'Deaths_' + name]].dropna() for name in countries}

# %%
# Regular TimesSeriesModeller On Log Data
for total in totals:
    try: 
        Y = log_totals[total]
        print total
        print ""
        print 'Cases ' + total
        modeller.fit(Y['Cases_' + total])
        print ""
        print 'Deaths ' + total
        modeller.fit(Y['Deaths_' + total])
        print ""
    except:
        pass
# Out:
# Liberia
#
# Cases Liberia
# model size: 1
# meansquarederror -0.054250
# model size: 2
# meansquarederror -0.035701
# model size: 3
# meansquarederror -0.032535
# model size: 4
# meansquarederror -0.041611
# model size: 5
# meansquarederror -0.036344
# model size: 6
# meansquarederror -0.060365
# model size: 7
# meansquarederror -0.061847
# model size: 8
# meansquarederror -0.068954
# model size: 9
# meansquarederror -0.071765
#
# Deaths Liberia
# model size: 1
# meansquarederror -0.081989
# model size: 2
# meansquarederror -0.058876
# model size: 3
# meansquarederror -0.034872
# model size: 4
# meansquarederror -0.081533
# model size: 5
# meansquarederror -0.085491
# model size: 6
# meansquarederror -0.093992
# model size: 7
# meansquarederror -0.055634
# model size: 8
# meansquarederror -0.065732
# model size: 9
# meansquarederror -0.052055
#
# Guinea
#
# Cases Guinea
# model size: 1
# meansquarederror -0.040672
# model size: 2
# meansquarederror -0.047440
# model size: 3
# meansquarederror -0.050419
# model size: 4
# meansquarederror -0.081556
# model size: 5
# meansquarederror -0.071112
# model size: 6
# meansquarederror -0.079298
# model size: 7
# meansquarederror -0.095130
# model size: 8
# meansquarederror -0.109055
# model size: 9
# meansquarederror -0.162702
#
# Deaths Guinea
# model size: 1
# meansquarederror -0.012587
# model size: 2
# meansquarederror -0.012147
# model size: 3
# meansquarederror -0.009339
# model size: 4
# meansquarederror -0.034764
# model size: 5
# meansquarederror -0.024289
# model size: 6
# meansquarederror -0.037731
# model size: 7
# meansquarederror -0.043949
# model size: 8
# meansquarederror -0.037600
# model size: 9
# meansquarederror -0.105214
#
# SierraLeone
#
# Cases SierraLeone
# Senegal
#
# Cases Senegal
# Mali
#
# Cases Mali
# model size: 1
# meansquarederror nan
# model size: 2
# meansquarederror nan
# model size: 3
# meansquarederror nan
# model size: 4
# meansquarederror nan
# model size: 5
# meansquarederror nan
# model size: 6
# meansquarederror nan
# model size: 7
# meansquarederror nan
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Deaths Mali
# model size: 1
# meansquarederror nan
# model size: 2
# meansquarederror nan
# model size: 3
# meansquarederror nan
# model size: 4
# meansquarederror nan
# model size: 5
# meansquarederror nan
# model size: 6
# meansquarederror nan
# model size: 7
# meansquarederror nan
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Nigeria
#
# Cases Nigeria
# Spain
# Cases Spain
# model size: 1
# meansquarederror nan
# model size: 2
# meansquarederror nan
# model size: 3
# meansquarederror nan
# UnitedStates
#
# Cases UnitedStates

# %%
# Most Recent Data Point Excluded TimesSeriesModeller On Log Data
for total in totals:
    try: 
        Y = totals[total]
        print total
        print ""
        print 'Cases ' + total
        modeller.fit_day_late(Y['Cases_' + total])
        print ""
        print 'Deaths ' + total
        modeller.fit(Y_day_late['Deaths_' + total])
        print ""
    except:
        pass
# Out:
# Liberia
#
# Cases Liberia
# model size: 1
# meansquarederror -5.022861
# model size: 2
# meansquarederror -3.508850
# model size: 3
# meansquarederror -4.374172
# model size: 4
# meansquarederror -4.125199
# model size: 5
# meansquarederror -2.395413
# model size: 6
# meansquarederror -3.275559
# model size: 7
# meansquarederror -2.357059
# model size: 8
# meansquarederror -4.090205
# model size: 9
# meansquarederror -4.948956
#
# Deaths Liberia
# Guinea
#
# Cases Guinea
# model size: 1
# meansquarederror -0.184874
# model size: 2
# meansquarederror -0.139145
# model size: 3
# meansquarederror -0.055243
# model size: 4
# meansquarederror -0.248973
# model size: 5
# meansquarederror -0.002690
# model size: 6
# meansquarederror 0.003181
# model size: 7
# meansquarederror -0.118235
# model size: 8
# meansquarederror 0.059077
# model size: 9
# meansquarederror -0.025396
#
# Deaths Guinea
# SierraLeone
#
# Cases SierraLeone
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror -inf
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror nan
#
# Deaths SierraLeone
# Senegal
#
# Cases Senegal
# model size: 1
# meansquarederror 0.060606
# model size: 2
# meansquarederror 0.082474
# model size: 3
# meansquarederror 0.064516
# model size: 4
# meansquarederror 0.079470
# model size: 5
# meansquarederror 0.068966
# model size: 6
# meansquarederror 0.081218
# model size: 7
# meansquarederror 0.074074
# model size: 8
# meansquarederror 0.085106
# model size: 9
# meansquarederror 0.080000
#
# Deaths Senegal
# Mali
#
# Cases Mali
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Mali
# Nigeria
#
# Cases Nigeria
# model size: 1
# meansquarederror -inf
# model size: 2
# meansquarederror -inf
# model size: 3
# meansquarederror -inf
# model size: 4
# meansquarederror -inf
# model size: 5
# meansquarederror nan
# model size: 6
# meansquarederror -inf
# model size: 7
# meansquarederror -inf
# model size: 8
# meansquarederror nan
# model size: 9
# meansquarederror -inf
#
# Deaths Nigeria
# Spain
#
# Cases Spain
# model size: 1
# meansquarederror 0.000000
# model size: 2
# meansquarederror 0.000000
# model size: 3
# meansquarederror 0.000000
# model size: 4
# meansquarederror 0.000000
# model size: 5
# meansquarederror 0.000000
# model size: 6
# meansquarederror 0.000000
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror 0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths Spain
# UnitedStates
#
# Cases UnitedStates
# model size: 1
# meansquarederror -0.000000
# model size: 2
# meansquarederror 0.006623
# model size: 3
# meansquarederror -0.000000
# model size: 4
# meansquarederror 0.066858
# model size: 5
# meansquarederror 0.032396
# model size: 6
# meansquarederror 0.036383
# model size: 7
# meansquarederror 0.000000
# model size: 8
# meansquarederror -0.000000
# model size: 9
# meansquarederror 0.000000
#
# Deaths UnitedStates

# %%
for k in log_totals:
    log_totals[k].plot()
    plt.title(k)
    show()

# %%
# Plot Cases and Deaths for Log
log_cases = log_df[cases_column]
log_cases.plot()
show()

log_deaths = log_df[deaths_column]
log_deaths.plot()
show()
