# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from random import choice
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns


df = pd.DataFrame.from_csv('https://raw.githubusercontent.com/cmrivers/ebola/master/country_timeseries.csv',
                 index_col=0)

# %%
#reproduce epidemic curves for each county
df.columns
# Out:
# Index([u'Day', u'Cases_Guinea', u'Cases_Liberia', u'Cases_SierraLeone', u'Cases_Nigeria', u'Cases_Senegal', u'Cases_UnitedStates', u'Cases_Spain', u'Cases_Mali', u'Deaths_Guinea', u'Deaths_Liberia', u'Deaths_SierraLeone', u'Deaths_Nigeria', u'Deaths_Senegal', u'Deaths_UnitedStates', u'Deaths_Spain', u'Deaths_Mali'], dtype='object')

# %%
df.describe()
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# count   91.000000     73.000000      66.000000          67.000000
# mean   107.329670    527.410959    1005.969697         860.820896
# std     70.495556    430.600931    1556.346352        1161.742238
# min      0.000000     49.000000       3.000000           0.000000
# 25%     37.500000    224.000000      13.000000           2.000000
# 50%    108.000000    409.000000     157.000000         397.000000
# 75%    173.500000    648.000000    1304.000000        1238.500000
# max    218.000000   1906.000000    6535.000000        5235.000000
#
#        Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# count      28.000000      15.000000             8.00000            6
# mean       15.571429       1.133333             2.37500            1
# std         6.630058       0.516398             1.30247            0
# min         0.000000       1.000000             1.00000            1
# ...

# %%
df.sort("Day")
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-03-22    0            49            NaN                NaN
# 2014-03-24    2            86            NaN                NaN
# 2014-03-25    3            86            NaN                NaN
# 2014-03-26    4            86            NaN                NaN
# 2014-03-27    5           103              8                  6
# 2014-03-28    6           112              3                  2
# 2014-03-29    7           112              7                NaN
# 2014-03-31    9           122              8                  2
# 2014-04-01   10           127              8                  2
# 2014-04-04   13           143             18                  2
# 2014-04-07   16           151             21                  2
# 2014-04-09   18           158             25                  2
# 2014-04-11   20           159             26                  2
# 2014-04-14   23           168            NaN                NaN
# ...

# %%
df = df.interpolate()

# %%
cases_cols=[]
deaths_cols=[]

for column in df.columns:
    print column
    tmp = column.split("_")
    if tmp[0] == 'Cases':
        cases_cols.append(column)
    if tmp[0] == 'Deaths':
        deaths_cols.append(column)
        
print cases_cols
print deaths_cols
# Out:
# Day
# Cases_Guinea
# Cases_Liberia
# Cases_SierraLeone
# Cases_Nigeria
# Cases_Senegal
# Cases_UnitedStates
# Cases_Spain
# Cases_Mali
# Deaths_Guinea
# Deaths_Liberia
# Deaths_SierraLeone
# Deaths_Nigeria
# Deaths_Senegal
# Deaths_UnitedStates
# Deaths_Spain
# Deaths_Mali
# ['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone', 'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain', 'Cases_Mali']
# ['Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone', 'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates', 'Deaths_Spain', 'Deaths_Mali']

# %%
deaths_df = df[deaths_cols]

# %%
cases_cols
# Out:
# ['Cases_Guinea',
#  'Cases_Liberia',
#  'Cases_SierraLeone',
#  'Cases_Nigeria',
#  'Cases_Senegal',
#  'Cases_UnitedStates',
#  'Cases_Spain',
#  'Cases_Mali']

# %%
cases_df = df[cases_cols]

# %%
cases_df.plot()

# %%
deaths_df.plot()

# %%
#Liberia = pd.Series(deaths_df["Deaths_Liberia"])

# %%
Liberia = pd.DataFrame(deaths_df["Deaths_Liberia"])

# %%
Liberia =  Liberia.bfill()

# %%
Liberia[0:10]
# Out:
#             Deaths_Liberia
# Date
# 2014-10-27          2413.0
# 2014-10-25          2413.0
# 2014-10-22          2486.0
# 2014-10-21          2559.0
# 2014-10-19          2632.0
# 2014-10-18          2705.0
# 2014-10-14          2594.5
# 2014-10-13          2484.0
# 2014-10-12          2471.0
# 2014-10-11          2458.0

# %%
#def acf(df):
df = Liberia
lagged = pd.concat([df.shift(i) for i in range(10)], axis = 1)
lagged.columns = ["lag %0.2d" % (i) for i in range(10)]
#print lagged
#print lagged.columns
sns.corrplot(lagged)
